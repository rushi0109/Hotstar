# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/rushi0109/Hotstar/blob/master/hotstar_1.ipynb)

# %%
# !wget https://he-s3.s3.amazonaws.com/media/hackathon/machine-learning-indiahacks-2017/5f828822-4--4-hotstar_dataset.zip
# !unzip 5f828822-4--4-hotstar_dataset.zip
# Out:
# --2018-08-26 09:09:48--  https://he-s3.s3.amazonaws.com/media/hackathon/machine-learning-indiahacks-2017/5f828822-4--4-hotstar_dataset.zip
# Resolving he-s3.s3.amazonaws.com (he-s3.s3.amazonaws.com)... 52.219.40.140
# Connecting to he-s3.s3.amazonaws.com (he-s3.s3.amazonaws.com)|52.219.40.140|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51766669 (49M) [application/zip]
# Saving to: ‘5f828822-4--4-hotstar_dataset.zip.1’
#
# 5f828822-4--4-hotst 100%[===================>]  49.37M  9.25MB/s    in 14s
#
# 2018-08-26 09:10:02 (3.62 MB/s) - ‘5f828822-4--4-hotstar_dataset.zip.1’ saved [51766669/51766669]
#
# Archive:  5f828822-4--4-hotstar_dataset.zip
# replace sample_submission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
import numpy as np
import pandas as pd
import re
train_data = pd.read_json('train_data.json',orient='index')

# %%
train_data['g1'] = [re.sub(pattern='\:\d+',repl='',string=x) for x in train_data['genres']]
train_data['g1'] = train_data['g1'].apply(lambda x: x.split(','))
t1 = pd.Series(train_data['g1']).apply(frozenset).to_frame(name='t_genre')
genreSet = frozenset.union(*t1.t_genre)

# %%
def string_genres_time(genre, string):
 if genre in string:
   prbmStr = string[string.index(genre) :]
   #print(prbmStr)
   problemStr = prbmStr[prbmStr.index(':')+1:]
   #print(problemStr)
   #print(problemStr.index(','))
   if ',' in problemStr:
     return int(problemStr[0:problemStr.index(',')])
   else:
     return int(problemStr[0:])
 else:
   return 0

# %%
def string_dow_time(genre, string):
 if genre in string:
   prbmStr = string[string.index(genre) :]
   #print(prbmStr)
   problemStr = prbmStr[prbmStr.index(':')+1:]
   #print(problemStr)
   #print(problemStr.index(','))
   if ',' in problemStr:
     return int(problemStr[0:problemStr.index(',')])
   else:
     return int(problemStr[0:])
 else:
   return 0

# %%
def string_tod_time(genre, string):
	if genre in string:
		prbmStr = string[string.index(genre) :]
		#print(prbmStr)
		problemStr = prbmStr[prbmStr.index(':')+1:]
		#print(problemStr)
		#print(problemStr.index(','))
		if ',' in problemStr:
			return int(problemStr[0:problemStr.index(',')])
		else:
			return int(problemStr[0:])
	else:
		todData = genre[1:]
		if todData in string:
			if string.index(todData) == 0:
				prbmStr = string[string.index(todData) :]
				#print(prbmStr)
				problemStr = prbmStr[prbmStr.index(':')+1:]
				#print(problemStr)
				#print(problemStr.index(','))
				if ',' in problemStr:
					return int(problemStr[0:problemStr.index(',')])
				else:
					return int(problemStr[0:])
			else:
				return 0
		else:
			return 0

# %%
for i in genreSet:
  train_data[i] = train_data["genres"].apply(lambda x : string_genres_time(i, x))

# %%
for i in np.arange(1,8):
  str_i = str(i) + ':'
  train_data[i] = train_data["dow"].apply(lambda x : string_dow_time(str_i, x))

# %%
for i in np.arange(0,24):
  str_i = ','+str(i)+':'
  colName = 'tod_'+str(i)
  train_data[colName] = train_data["tod"].apply(lambda x : string_genres_time(str_i, x))

# %%
train_data.head().T
# Out:
#                                                        train-1  \
# cities                               gurgaon:55494,delhi:31892
# dow          1:3412,3:15878,2:1737,5:10975,4:20974,7:17820,...
# genres                  Cricket:82379,Kabaddi:255,Reality:4751
# segment                                                    neg
# titles       Top Raids: Haryana vs Services SCB:103,Day 4: ...
# tod          10:26,13:331,12:323,20:21864,21:16233,17:7953,...
# g1                                 [Cricket, Kabaddi, Reality]
# Football                                                     0
# Romance                                                      0
# Reality                                                   4751
# Crime                                                        0
# Action                                                       0
# Badminton                                                    0
# Cricket                                                  82379
# Sport                                                        0
# Kids                                                         0
# Wildlife                                                     0
# Documentary                                                  0
# Volleyball                                                   0
# Science                                                      0
# FormulaE                                                     0
# Mythology                                                    0
# NA                                                           0
# IndiaVsSa                                                    0
# Family                                                       0
# Hockey                                                       0
# Teen                                                         0
# Formula1                                                     0
# Boxing                                                       0
# Awards                                                       0
# ...                                                        ...
# 2                                                         1737
# 3                                                        15878
# 4                                                        20974
# 5                                                        10975
# 6                                                        16580
# 7                                                        17820
# tod_0                                                        0
# tod_1                                                        0
# tod_2                                                     2363
# tod_3                                                        0
# tod_4                                                        0
# tod_5                                                        0
# tod_6                                                        0
# tod_7                                                        0
# tod_8                                                        0
# tod_9                                                        0
# tod_10                                                       0
# tod_11                                                       0
# tod_12                                                     323
# tod_13                                                     331
# tod_14                                                    2196
# tod_15                                                    2901
# tod_16                                                    1725
# tod_17                                                    7953
# tod_18                                                    6017
# tod_19                                                   11505
# tod_20                                                   21864
# tod_21                                                   16233
# tod_22                                                    8894
# tod_23                                                    5046
#
#                                                       train-10  \
# cities                       delhi:5862,nagar:8916,mumbai:1593
# dow              1:5745,3:3025,2:3346,5:123,4:3007,7:1108,6:10
# genres                              Cricket:15640,Wildlife:730
# segment                                                    neg
# titles       Dhoni Quits Captaincy:148,Day 4: India Move in...
# tod          11:1661,10:384,20:401,21:798,22:221,16:525,19:...
# g1                                         [Cricket, Wildlife]
# Football                                                     0
# Romance                                                      0
# Reality                                                      0
# Crime                                                        0
# Action                                                       0
# Badminton                                                    0
# Cricket                                                  15640
# Sport                                                        0
# Kids                                                         0
# Wildlife                                                   730
# Documentary                                                  0
# Volleyball                                                   0
# Science                                                      0
# FormulaE                                                     0
# Mythology                                                    0
# NA                                                           0
# IndiaVsSa                                                    0
# Family                                                       0
# Hockey                                                       0
# Teen                                                         0
# Formula1                                                     0
# Boxing                                                       0
# Awards                                                       0
# ...                                                        ...
# 2                                                         3346
# 3                                                         3025
# 4                                                         3007
# 5                                                          123
# 6                                                           10
# 7                                                         1108
# tod_0                                                        0
# tod_1                                                      961
# tod_2                                                     1564
# tod_3                                                     1617
# tod_4                                                        0
# tod_5                                                      305
# tod_6                                                        0
# tod_7                                                        0
# tod_8                                                      241
# tod_9                                                      374
# tod_10                                                     384
# tod_11                                                       0
# tod_12                                                       0
# tod_13                                                       0
# tod_14                                                       0
# tod_15                                                    1201
# tod_16                                                     525
# tod_17                                                       0
# tod_18                                                    1722
# tod_19                                                    4231
# tod_20                                                     401
# tod_21                                                     798
# tod_22                                                     221
# tod_23                                                     155
#
#                                                      train-100  \
# cities                                        navi mumbai:4142
# dow                                                     3:4142
# genres                                 LiveTV:13,Football:4129
# segment                                                    neg
# titles       Star Sports 4:13,Manchester United vs Everton:...
# tod                                        1:1207,0:2406,2:529
# g1                                          [LiveTV, Football]
# Football                                                  4129
# Romance                                                      0
# Reality                                                      0
# Crime                                                        0
# Action                                                       0
# Badminton                                                    0
# Cricket                                                      0
# Sport                                                        0
# Kids                                                         0
# Wildlife                                                     0
# Documentary                                                  0
# Volleyball                                                   0
# Science                                                      0
# FormulaE                                                     0
# Mythology                                                    0
# NA                                                           0
# IndiaVsSa                                                    0
# Family                                                       0
# Hockey                                                       0
# Teen                                                         0
# Formula1                                                     0
# Boxing                                                       0
# Awards                                                       0
# ...                                                        ...
# 2                                                            0
# 3                                                         4142
# 4                                                            0
# 5                                                            0
# 6                                                            0
# 7                                                            0
# tod_0                                                     2406
# tod_1                                                        0
# tod_2                                                      529
# tod_3                                                        0
# tod_4                                                        0
# tod_5                                                        0
# tod_6                                                        0
# tod_7                                                        0
# tod_8                                                        0
# tod_9                                                        0
# tod_10                                                       0
# tod_11                                                       0
# tod_12                                                       0
# tod_13                                                       0
# tod_14                                                       0
# tod_15                                                       0
# tod_16                                                       0
# tod_17                                                       0
# tod_18                                                       0
# tod_19                                                       0
# tod_20                                                       0
# tod_21                                                       0
# tod_22                                                       0
# tod_23                                                       0
#
#                                                     train-1000  \
# cities            new delhi:4131,chennai:2878,navi mumbai:1339
# dow                             1:658,3:5867,5:413,4:1339,7:71
# genres                               TalkShow:658,Cricket:7690
# segment                                                    neg
# titles       SRH vs RCB:701,KKR vs KXIP:1042,MI vs SRH:2288...
# tod                11:71,20:2417,21:1042,23:2288,19:1872,8:658
# g1                                         [TalkShow, Cricket]
# Football                                                     0
# Romance                                                      0
# Reality                                                      0
# Crime                                                        0
# Action                                                       0
# Badminton                                                    0
# Cricket                                                   7690
# Sport                                                        0
# Kids                                                         0
# Wildlife                                                     0
# Documentary                                                  0
# Volleyball                                                   0
# Science                                                      0
# FormulaE                                                     0
# Mythology                                                    0
# NA                                                           0
# IndiaVsSa                                                    0
# Family                                                       0
# Hockey                                                       0
# Teen                                                         0
# Formula1                                                     0
# Boxing                                                       0
# Awards                                                       0
# ...                                                        ...
# 2                                                            0
# 3                                                         5867
# 4                                                         1339
# 5                                                          413
# 6                                                            0
# 7                                                           71
# tod_0                                                        0
# tod_1                                                        0
# tod_2                                                        0
# tod_3                                                        0
# tod_4                                                        0
# tod_5                                                        0
# tod_6                                                        0
# tod_7                                                        0
# tod_8                                                      658
# tod_9                                                        0
# tod_10                                                       0
# tod_11                                                       0
# tod_12                                                       0
# tod_13                                                       0
# tod_14                                                       0
# tod_15                                                       0
# tod_16                                                       0
# tod_17                                                       0
# tod_18                                                       0
# tod_19                                                    1872
# tod_20                                                    2417
# tod_21                                                    1042
# tod_22                                                       0
# tod_23                                                    2288
#
#                                                    train-10000
# cities                               gurgaon:6077,chennai:4055
# dow                          1:1641,2:480,4:1445,7:1663,6:4900
# genres                    Drama:5503,Cricket:3283,Reality:1345
# segment                                                    neg
# titles       MI vs KKR:304,Yeh Rishta Kya Kehlata Hai:5449,...
# tod          20:158,22:4139,17:67,23:1510,19:288,18:56,0:23...
# g1                                   [Drama, Cricket, Reality]
# Football                                                     0
# Romance                                                      0
# Reality                                                   1345
# Crime                                                        0
# Action                                                       0
# Badminton                                                    0
# Cricket                                                   3283
# Sport                                                        0
# Kids                                                         0
# Wildlife                                                     0
# Documentary                                                  0
# Volleyball                                                   0
# Science                                                      0
# FormulaE                                                     0
# Mythology                                                    0
# NA                                                           0
# IndiaVsSa                                                    0
# Family                                                       0
# Hockey                                                       0
# Teen                                                         0
# Formula1                                                     0
# Boxing                                                       0
# Awards                                                       0
# ...                                                        ...
# 2                                                          480
# 3                                                            0
# 4                                                         1445
# 5                                                            0
# 6                                                         4900
# 7                                                         1663
# tod_0                                                     2395
# tod_1                                                        0
# tod_2                                                        0
# tod_3                                                        0
# tod_4                                                        0
# tod_5                                                        0
# tod_6                                                        0
# tod_7                                                        0
# tod_8                                                        0
# tod_9                                                        0
# tod_10                                                       0
# tod_11                                                       0
# tod_12                                                       0
# tod_13                                                       0
# tod_14                                                       0
# tod_15                                                    1359
# tod_16                                                       0
# tod_17                                                      67
# tod_18                                                      56
# tod_19                                                     288
# tod_20                                                       0
# tod_21                                                     157
# tod_22                                                    4139
# tod_23                                                    1510
#
# [73 rows x 5 columns]

# %%
train_data.drop(['g1','tod','dow','genres'],inplace=True,axis=1)

# %%
train_data_backup = train_data.copy()

# %%
train_data.drop(['titles','cities'],inplace=True,axis=1)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200000 entries, train-1 to train-99999
# Data columns (total 67 columns):
# segment         200000 non-null object
# Football        200000 non-null int64
# Romance         200000 non-null int64
# Reality         200000 non-null int64
# Crime           200000 non-null int64
# Action          200000 non-null int64
# Badminton       200000 non-null int64
# Cricket         200000 non-null int64
# Sport           200000 non-null int64
# Kids            200000 non-null int64
# Wildlife        200000 non-null int64
# Documentary     200000 non-null int64
# Volleyball      200000 non-null int64
# Science         200000 non-null int64
# FormulaE        200000 non-null int64
# Mythology       200000 non-null int64
# NA              200000 non-null int64
# IndiaVsSa       200000 non-null int64
# Family          200000 non-null int64
# Hockey          200000 non-null int64
# Teen            200000 non-null int64
# Formula1        200000 non-null int64
# Boxing          200000 non-null int64
# Awards          200000 non-null int64
# TalkShow        200000 non-null int64
# Table Tennis    200000 non-null int64
# Travel          200000 non-null int64
# LiveTV          200000 non-null int64
# Horror          200000 non-null int64
# Athletics       200000 non-null int64
# Thriller        200000 non-null int64
# Comedy          200000 non-null int64
# Drama           200000 non-null int64
# Tennis          200000 non-null int64
# Swimming        200000 non-null int64
# Kabaddi         200000 non-null int64
# 1               200000 non-null int64
# 2               200000 non-null int64
# 3               200000 non-null int64
# 4               200000 non-null int64
# 5               200000 non-null int64
# 6               200000 non-null int64
# 7               200000 non-null int64
# tod_0           200000 non-null int64
# tod_1           200000 non-null int64
# tod_2           200000 non-null int64
# tod_3           200000 non-null int64
# tod_4           200000 non-null int64
# tod_5           200000 non-null int64
# tod_6           200000 non-null int64
# tod_7           200000 non-null int64
# tod_8           200000 non-null int64
# tod_9           200000 non-null int64
# tod_10          200000 non-null int64
# tod_11          200000 non-null int64
# tod_12          200000 non-null int64
# tod_13          200000 non-null int64
# tod_14          200000 non-null int64
# tod_15          200000 non-null int64
# tod_16          200000 non-null int64
# tod_17          200000 non-null int64
# tod_18          200000 non-null int64
# tod_19          200000 non-null int64
# tod_20          200000 non-null int64
# tod_21          200000 non-null int64
# tod_22          200000 non-null int64
# tod_23          200000 non-null int64
# dtypes: int64(66), object(1)
# memory usage: 103.8+ MB

# %%
train_data.segment.unique()
# Out:
# array(['neg', 'pos'], dtype=object)

# %%
train_data.segment.replace('neg',0,inplace=True)

# %%
train_data.segment.replace('pos',1,inplace=True)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200000 entries, train-1 to train-99999
# Data columns (total 67 columns):
# segment         200000 non-null int64
# Football        200000 non-null int64
# Romance         200000 non-null int64
# Reality         200000 non-null int64
# Crime           200000 non-null int64
# Action          200000 non-null int64
# Badminton       200000 non-null int64
# Cricket         200000 non-null int64
# Sport           200000 non-null int64
# Kids            200000 non-null int64
# Wildlife        200000 non-null int64
# Documentary     200000 non-null int64
# Volleyball      200000 non-null int64
# Science         200000 non-null int64
# FormulaE        200000 non-null int64
# Mythology       200000 non-null int64
# NA              200000 non-null int64
# IndiaVsSa       200000 non-null int64
# Family          200000 non-null int64
# Hockey          200000 non-null int64
# Teen            200000 non-null int64
# Formula1        200000 non-null int64
# Boxing          200000 non-null int64
# Awards          200000 non-null int64
# TalkShow        200000 non-null int64
# Table Tennis    200000 non-null int64
# Travel          200000 non-null int64
# LiveTV          200000 non-null int64
# Horror          200000 non-null int64
# Athletics       200000 non-null int64
# Thriller        200000 non-null int64
# Comedy          200000 non-null int64
# Drama           200000 non-null int64
# Tennis          200000 non-null int64
# Swimming        200000 non-null int64
# Kabaddi         200000 non-null int64
# 1               200000 non-null int64
# 2               200000 non-null int64
# 3               200000 non-null int64
# 4               200000 non-null int64
# 5               200000 non-null int64
# 6               200000 non-null int64
# 7               200000 non-null int64
# tod_0           200000 non-null int64
# tod_1           200000 non-null int64
# tod_2           200000 non-null int64
# tod_3           200000 non-null int64
# tod_4           200000 non-null int64
# tod_5           200000 non-null int64
# tod_6           200000 non-null int64
# tod_7           200000 non-null int64
# tod_8           200000 non-null int64
# tod_9           200000 non-null int64
# tod_10          200000 non-null int64
# tod_11          200000 non-null int64
# tod_12          200000 non-null int64
# tod_13          200000 non-null int64
# tod_14          200000 non-null int64
# tod_15          200000 non-null int64
# tod_16          200000 non-null int64
# tod_17          200000 non-null int64
# tod_18          200000 non-null int64
# tod_19          200000 non-null int64
# tod_20          200000 non-null int64
# tod_21          200000 non-null int64
# tod_22          200000 non-null int64
# tod_23          200000 non-null int64
# dtypes: int64(67)
# memory usage: 103.8+ MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_data_count = train_data.copy()

# %%
train_data_count[train_data_count !=0 ] = 1

# %%
train_data_count['genre_counts'] = train_data_count[list(genreSet)].sum(axis=1)

# %%
train_data_count['genre_counts'].value_counts()
# Out:
# 2     56332
# 3     39742
# 1     33047
# 4     26489
# 5     17220
# 6     11085
# 7      6883
# 8      4110
# 9      2290
# 10     1350
# 11      724
# 12      350
# 13      195
# 14      102
# 15       48
# 16       22
# 17        7
# 19        2
# 18        1
# 22        1
# Name: genre_counts, dtype: int64

# %%
sns.countplot(train_data_count['genre_counts'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
sns.countplot(train_data_count['genre_counts'][train_data_count['segment'] == 1])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
for col in train_data_count.columns:
  plt.figure(1,figsize=(18,6))  
  plt.subplot(231)
  plt.title(' 1')
  sns.countplot(train_data_count[col][train_data_count['segment'] == 1])
  plt.subplot(232)
  plt.title(' 0')
  sns.countplot(train_data_count[col][train_data_count['segment'] == 0])
  plt.subplot(233)
  plt.title('Box Plot')
  sns.boxplot(x = train_data.segment,y=train_data[col]/100000) 
  plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genre_counts'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-0de36fce7c15> in <module>()
#       9   plt.subplot(233)
#      10   plt.title('Box Plot')
# ---> 11   sns.boxplot(x = train_data.segment,y=train_data[col]/100000)
#      12   plt.show()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genre_counts'

# %%
#for col in train_data_count.columns:
#  sns.countplot(train_data_count[col][train_data_count['segment'] == 0])
#  plt.show()

# %%
  train_data['total_time_spent'] = train_data[list(genreSet)].sum(axis=1)

# %%
train_data['total_time_spent'] = train_data['total_time_spent']/3600

# %%
train_data['total_time_spent'].astype(np.int,inplace = True)
# Out:
# train-1         24
# train-10         4
# train-100        1
# train-1000       2
# train-10000      2
# train-100000    15
# train-100001     2
# train-100002     3
# train-100003     0
# train-100004     4
# train-100005     1
# train-100006     0
# train-100007    39
# train-100008     2
# train-100009     0
# train-10001      1
# train-100010     1
# train-100011     0
# train-100012     9
# train-100013     7
# train-100014     5
# train-100015    21
# train-100016     0
# train-100017     0
# train-100018     0
# train-100019     2
# train-10002      0
# train-100020    14
# train-100021     1
# train-100022     0
#                 ..
# train-99972      0
# train-99973      3
# train-99974      5
# train-99975      1
# train-99976      5
# train-99977     61
# train-99978      0
# train-99979      0
# train-9998       0
# train-99980     18
# train-99981      7
# train-99982      0
# train-99983      1
# train-99984      2
# train-99985      1
# train-99986      2
# train-99987      4
# train-99988      0
# train-99989     11
# train-9999       0
# train-99990      3
# train-99991     51
# train-99992      7
# train-99993      0
# train-99994     44
# train-99995      1
# train-99996     13
# train-99997      0
# train-99998      7
# train-99999      1
# Name: total_time_spent, Length: 200000, dtype: int64

# %%
train_data['total_time_spent'].describe()
# Out:
# count    200000.000000
# mean          5.901987
# std          12.822070
# min           0.000278
# 25%           0.428611
# 50%           1.873056
# 75%           5.920347
# max         556.647778
# Name: total_time_spent, dtype: float64

# %%
#train_data['total_time_spent_except_Cricket'] = train_data['total_time_spent'] - train_data['Cricket']
genreList = list(genreSet)
genreList.remove('Cricket')

# %%
train_data['total_time_spent_except_Cricket'] = train_data[genreList].sum(axis=1)

# %%
sns.boxplot(x=train_data['segment'],y=train_data['total_time_spent_except_Cricket']/3600)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
sum_data = train_data_count.drop(['genre_counts','segment'],axis=1).sum(axis=0)

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.barplot(y = sum_data.values,x=sum_data.index)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# From the above graphs, It is visible that
# 1. Cricket,Drama,Romance,Reality,TalkShow,Family,Comedy are one of the favorite Genres and people tend to watch them more. Where Cricket is the top watched genre.
# 2. People watch more on Hotstar on 4th day of a week and less on 2nd Day of a week.
# 3. People tend to watch more on Hotstar on second half of the day.
# 4. Segment point of view,
#
#
# 1.   Romance, Drama , Family and Talkshow are more contributor for positive segment
# 2.   Hour 14,15,16,17,21,22,23 are more contributing for positive segment
